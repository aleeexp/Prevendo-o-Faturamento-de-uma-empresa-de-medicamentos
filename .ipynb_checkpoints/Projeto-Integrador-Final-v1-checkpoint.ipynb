# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline

# %%
# %%time
data_location = "data/Faturamento.csv"
data = pd.read_csv(data_location, sep = ";", low_memory=False, encoding="latin-1")
# Out:
# CPU times: total: 219 ms
# Wall time: 215 ms

# %%
data.head(5)
# Out:
#     ANO  MES  TRIMESTRE      DESCRICAO_GRUPO  UF      CIDADE  \
# 0  2014    5          2            SANEANTES  SC  RIO DO SUL
# 1  2014    6          2  PRODUTOS PARA SAUDE  SC  RIO DO SUL
# 2  2014    7          3          LABORATORIO  SC  RIO DO SUL
# 3  2016    6          2  PRODUTOS PARA SAUDE  SC  RIO DO SUL
# 4  2017    1          1  PRODUTOS PARA SAUDE  SC  RIO DO SUL
#
#    ELEICAO_MUNICIPAL  ELEICAO_FEDERAL VARIACAO_DOLAR INFLACAO   PIB     VALOR
# 0                  0                1    14,40010277     6,41   0,5   1868,99
# 1                  0                1    14,40010277     6,41   0,5  27279,04
# 2                  0                1    14,40010277     6,41   0,5    214,12
# 3                  1                0   -12,59075524     6,29  -3,3  46374,06
# 4                  0                0   -2,944132427     2,95   1,3  32043,56

# %%
print("Total rows: {0}".format(len(data)))
# Out:
# Total rows: 164959

# %% [markdown]
# Verificando Tipos dos Dados

# %%
print('\nInformações do dataset\n')
print(data.info())
print('\n---------------------------------------------\n')
# Out:
# Informações do dataset
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164959 entries, 0 to 164958
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ANO                164959 non-null  int64
#  1   MES                164959 non-null  int64
#  2   TRIMESTRE          164959 non-null  int64
#  3   DESCRICAO_GRUPO    164959 non-null  object
#  4   UF                 164959 non-null  object
#  5   CIDADE             164959 non-null  object
#  6   ELEICAO_MUNICIPAL  164959 non-null  int64
#  7   ELEICAO_FEDERAL    164959 non-null  int64
#  8   VARIACAO_DOLAR     164959 non-null  object
#  9   INFLACAO           164959 non-null  object
#  10  PIB                164959 non-null  object
#  11  VALOR              164959 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 15.1+ MB
# None
#
# ---------------------------------------------

# %% [markdown]
# Alteração das colunas VARIACAO_DOLAR, INFLACAO, PIB, QUANTIDADE, VALOR dtype object para float

# %%
data['VARIACAO_DOLAR'] =data['VARIACAO_DOLAR'].apply(lambda x: x.replace(',', '.')).astype('float')
data['INFLACAO'] =data['INFLACAO'].apply(lambda x: x.replace(',', '.')).astype('float')
data['PIB'] =data['PIB'].apply(lambda x: x.replace(',', '.')).astype('float')
data['VALOR'] =data['VALOR'].apply(lambda x: x.replace(',', '.')).astype('float')

# %% [markdown]
# Alteração das colunas ANO e MES para string

# %%
data["ANO"] = data["ANO"].astype("str")
data["MES"] = data["MES"].astype("str")
data["TRIMESTRE"] = data["TRIMESTRE"].astype("str")

# %% [markdown]
# Eliminando linhas com o Ano de 2022 porque não temos o Faturamento total ainda

# %%
mask_ano_2022 = data['ANO']=='2022'
df_drop_ano_2022 = data.loc[mask_ano_2022]

data.drop(df_drop_ano_2022.index, inplace=True)

# %%
data.isnull().sum()
# Out:
# ANO                  0
# MES                  0
# TRIMESTRE            0
# DESCRICAO_GRUPO      0
# UF                   0
# CIDADE               0
# ELEICAO_MUNICIPAL    0
# ELEICAO_FEDERAL      0
# VARIACAO_DOLAR       0
# INFLACAO             0
# PIB                  0
# VALOR                0
# dtype: int64

# %%
print('\nConjunto de dados, linhas e colunas\n')
print('Shape:',data.shape)
print('\n---------------------------------------------\n')

print('\nCheck valores nulos\n')
print('Check nulos: \n')
print(pd.isnull(data).sum())
print('\n---------------------------------------------\n')

print('\nEstatísticas\n')
print(data.describe())
print('\n---------------------------------------------\n')
# Out:
# Conjunto de dados, linhas e colunas
#
# Shape: (152314, 12)
#
# ---------------------------------------------
#
#
# Check valores nulos
#
# Check nulos:
#
# ANO                  0
# MES                  0
# TRIMESTRE            0
# DESCRICAO_GRUPO      0
# UF                   0
# CIDADE               0
# ELEICAO_MUNICIPAL    0
# ELEICAO_FEDERAL      0
# VARIACAO_DOLAR       0
# INFLACAO             0
# PIB                  0
# VALOR                0
# dtype: int64
#
# ---------------------------------------------
#
#
# Estatísticas
#
#        ELEICAO_MUNICIPAL  ELEICAO_FEDERAL  VARIACAO_DOLAR       INFLACAO  \
# count      152314.000000    152314.000000   152314.000000  152314.000000
# mean            0.249885         0.212791       10.069452       5.999647
# std             0.432948         0.409282       16.729510       2.411692
# min             0.000000         0.000000      -25.888561       2.950000
# 25%             0.000000         0.000000       -2.944132       4.310000
# 50%             0.000000         0.000000       10.302183       5.840000
# 75%             0.000000         0.000000       15.502223       6.410000
# max             1.000000         1.000000       44.862821      10.670000
#
#                  PIB          VALOR
# count  152314.000000  152314.000000
# mean        0.747136    2998.975269
# std         3.196498   10197.568108
# min        -4.100000       0.040000
# 25%        -3.300000     240.000000
# 50%         1.300000     822.220000
# 75%         3.000000    2547.975000
# max         7.500000  655399.980000
#
# ---------------------------------------------

# %% [markdown]
# Plotando a correlaçao

# %%
plt.figure(figsize = (20,10))
plt.title('Correlation')
sns.heatmap(data.corr(), 
            annot = True, 
            vmin = -1, 
            cmap = 'Blues'
           );
#plt.savefig("../Correlation1.png", dpi = 600 )

# %% [markdown]
# ANALISANDO OS OUTLIERS

# %% [markdown]
# Plot valor vendido por ano

# %%
sns.catplot(y="ANO", x="VALOR",
                data=data.sort_values(by='ANO', ascending=False), kind="box",
                height=10, orient='h');

# %% [markdown]
# Criação de uma nova coluna DATA concatenando o mês e o ano e convertendo para datetime

# %%
s_mes = data.MES
data["MES"] = s_mes.str.zfill(2)
data['DATA']= '01' + data.MES + data.ANO
data['DATA']=pd.to_datetime(data['DATA'], format='%d%m%Y')
data[['ANO','MES','DATA']]
# Out:
#          ANO MES       DATA
# 0       2014  05 2014-05-01
# 1       2014  06 2014-06-01
# 2       2014  07 2014-07-01
# 3       2016  06 2016-06-01
# 4       2017  01 2017-01-01
# ...      ...  ..        ...
# 164950  2021  10 2021-10-01
# 164951  2021  11 2021-11-01
# 164956  2016  10 2016-10-01
# 164957  2016  10 2016-10-01
# 164958  2016  07 2016-07-01
#
# [152314 rows x 3 columns]

# %% [markdown]
# Criando mascara para definir se é ano eleitoral ou não

# %%
mask_el_fed = data.ELEICAO_FEDERAL == 1
dt_el_fed = data.loc[mask_el_fed, ['ANO']]

mask_el_mun = data.ELEICAO_MUNICIPAL == 1
dt_el_mun = data.loc[mask_el_mun, ['ANO']]

print('Anos eleitorais:', dt_el_fed.ANO.unique(), dt_el_mun.ANO.unique() )
# Out:
# Anos eleitorais: ['2014' '2018' '2010'] ['2016' '2020' '2012' '2008']

# %% [markdown]
# Criando de um dicionario e nova coluna classificando se é ano eleitoral ou não

# %%
ano_eleitoral = { "2008": 1,
                 "2009": 0,
                 "2010": 1,
                 "2011": 0,
                 "2012": 1,
                 "2013": 0,
                 "2014": 1,
                 "2015": 0,
                 "2016": 1,
                 "2017": 0,
                 "2018": 1,
                 "2019": 0,
                 "2020": 1,
                 "2021": 0,
                 "2022": 1
         }

data["ANO_ELEITORAL"] = data.ANO.map(ano_eleitoral)
data["ANO_ELEITORAL"] = data["ANO_ELEITORAL"].astype("category")

# %% [markdown]
# Verificando a nova coluna ANO_ELEITORAL

# %%
data[['ANO','ELEICAO_FEDERAL', 'ELEICAO_MUNICIPAL', 'ANO_ELEITORAL']]
# Out:
#          ANO  ELEICAO_FEDERAL  ELEICAO_MUNICIPAL ANO_ELEITORAL
# 0       2014                1                  0             1
# 1       2014                1                  0             1
# 2       2014                1                  0             1
# 3       2016                0                  1             1
# 4       2017                0                  0             0
# ...      ...              ...                ...           ...
# 164950  2021                0                  0             0
# 164951  2021                0                  0             0
# 164956  2016                0                  1             1
# 164957  2016                0                  1             1
# 164958  2016                0                  1             1
#
# [152314 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152314 entries, 0 to 164958
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ANO                152314 non-null  object
#  1   MES                152314 non-null  object
#  2   TRIMESTRE          152314 non-null  object
#  3   DESCRICAO_GRUPO    152314 non-null  object
#  4   UF                 152314 non-null  object
#  5   CIDADE             152314 non-null  object
#  6   ELEICAO_MUNICIPAL  152314 non-null  int64
#  7   ELEICAO_FEDERAL    152314 non-null  int64
#  8   VARIACAO_DOLAR     152314 non-null  float64
#  9   INFLACAO           152314 non-null  float64
#  10  PIB                152314 non-null  float64
#  11  VALOR              152314 non-null  float64
#  12  DATA               152314 non-null  datetime64[ns]
#  13  ANO_ELEITORAL      152314 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 16.4+ MB

# %% [markdown]
# ##################################################################################

# %% [markdown]
# Agrupamento por Valor e Data

# %%
vendasgb = data.groupby('DATA')['VALOR'].sum().reset_index()
vendasgb = data.set_index('DATA')

# %% [markdown]
# Criação de novo dataframe df_vendas_mes  downsampling   com resamplin

# %%
df_vendas_mes = vendasgb['VALOR'].resample('MS').mean().to_frame();
df_vendas_mes.head(5)
# Out:
#                   VALOR
# DATA
# 2008-12-01  2124.826051
# 2009-01-01  1365.677737
# 2009-02-01  1442.712601
# 2009-03-01  2351.546014
# 2009-04-01  2144.901965

# %%
plt.figure(figsize=(4,3)); 
df_vendas_mes.plot();
plt.show()

# %% [markdown]
# #################################################################

# %% [markdown]
# # ANÁLISE COM MODELOS SIMPLES

# %% [markdown]
# # 1- Tendência Linear

# %%
df_vendas_mes["DATAINDEX"] = pd.Series(np.arange(len(df_vendas_mes['VALOR'])), index = df_vendas_mes.index)
df_vendas_mes.DATAINDEX.head(3)
# Out:
# DATA
# 2008-12-01    0
# 2009-01-01    1
# 2009-02-01    2
# Freq: MS, Name: DATAINDEX, dtype: int32

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df_vendas_mes, test_size = 12, random_state = 42, shuffle = False)

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (145, 2)
# (12, 2)

# %%
import statsmodels.api as sm
sm.OLS.from_formula
# Out:
# <bound method Model.from_formula of <class 'statsmodels.regression.linear_model.OLS'>>

# %%
import statsmodels.formula.api as smf
model_linear = smf.ols(formula = 'VALOR ~ DATAINDEX', data = df_train).fit()

# %%
df_train["LinearTrend"] = model_linear.predict(df_train.DATAINDEX)
df_test["LinearTrend"] = model_linear.predict(df_test.DATAINDEX)

# %%
fig, axes = plt.subplots(1, 2,figsize = (12, 6))
df_train.plot(kind = "line", y = ["VALOR","LinearTrend"], ax = axes[0], title = 'Train');
df_test.plot(kind = "line", y = ["VALOR","LinearTrend"], ax = axes[1], title = 'Test');
plt.show()

# %% [markdown]
# Calculamos o desempenho com RMSE

# %%
df_Results = pd.DataFrame(columns = ["Model", "RMSE"])

# %%
def RMSE(predicted, actual):
	mse = (predicted - actual) ** 2
	rmse = np.sqrt(mse.sum() / mse.count())
	return rmse

# %%
model_RMSE = RMSE(df_test.LinearTrend, df_test.VALOR)

# %%
df_Results.loc[0, "Model"] = "LinearTrend"
df_Results.loc[0, "RMSE"] = model_RMSE
df_Results.head()
# Out:
#          Model        RMSE
# 0  LinearTrend  521.986297

# %%
model_linear.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  VALOR   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     328.6
# Date:                Mon, 19 Sep 2022   Prob (F-statistic):           7.06e-39
# Time:                        14:30:00   Log-Likelihood:                -1052.0
# No. Observations:                 145   AIC:                             2108.
# Df Residuals:                     143   BIC:                             2114.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1789.8848     56.978     31.414      0.000    1677.258    1902.512
# DATAINDEX     12.4012      0.684     18.126      0.000      11.049      13.754
# ==============================================================================
# Omnibus:                        7.943   Durbin-Watson:                   1.045
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                8.313
# Skew:                           0.433   Prob(JB):                       0.0157
# Kurtosis:                       3.792   Cond. No.                         166.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # 2 - Tendência quadrática

# %%
df_vendas_mes["DATAINDEX_SQ"] = df_vendas_mes["DATAINDEX"] ** 2
df_vendas_mes.DATAINDEX_SQ.head(3)
# Out:
# DATA
# 2008-12-01    0
# 2009-01-01    1
# 2009-02-01    4
# Freq: MS, Name: DATAINDEX_SQ, dtype: int32

# %%
df_train, df_test = train_test_split(df_vendas_mes, test_size = 12, random_state = 42, shuffle = False)

# %%
model_quadratic = smf.ols('VALOR ~ DATAINDEX + DATAINDEX_SQ', data = df_train).fit()

# %%
df_train["QUADRATIC_TEND"] = model_quadratic.predict(df_train[["DATAINDEX","DATAINDEX_SQ"]])
df_test["QUADRATIC_TEND"] = model_quadratic.predict(df_test[["DATAINDEX","DATAINDEX_SQ"]])

# %%
fig, axes = plt.subplots(1, 2,figsize = (12, 6))
df_train.plot(kind = "line", y = ["VALOR","QUADRATIC_TEND"], ax = axes[0], title = 'Train');
df_test.plot(kind = "line", y = ["VALOR","QUADRATIC_TEND"], ax = axes[1], title = 'Test');
plt.show()

# %%
model_RMSE = RMSE(df_test.QUADRATIC_TEND, df_test.VALOR)

# %%
df_Results.loc[1, "Model"] = "QUADRATIC_TEND"
df_Results.loc[1, "RMSE"] = model_RMSE
df_Results.head()
# Out:
#             Model        RMSE
# 0     LinearTrend  521.986297
# 1  QUADRATIC_TEND  503.214446

# %%
model_quadratic.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  VALOR   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     199.4
# Date:                Mon, 19 Sep 2022   Prob (F-statistic):           5.87e-42
# Time:                        14:30:14   Log-Likelihood:                -1041.5
# No. Observations:                 145   AIC:                             2089.
# Df Residuals:                     142   BIC:                             2098.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2064.5033     79.130     26.090      0.000    1908.078    2220.929
# DATAINDEX        0.8787      2.539      0.346      0.730      -4.141       5.898
# DATAINDEX_SQ     0.0800      0.017      4.689      0.000       0.046       0.114
# ==============================================================================
# Omnibus:                        4.713   Durbin-Watson:                   1.206
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                4.465
# Skew:                           0.303   Prob(JB):                        0.107
# Kurtosis:                       3.610   Cond. No.                     2.76e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # 3 -  Tendência com transformação logarítmica

# %%
df_train['LOG_VALOR'] = np.log(df_train['VALOR'])
df_test['LOG_VALOR'] = np.log(df_test['VALOR'])

# %%
fig, axes = plt.subplots(1, 2,figsize = (10, 5))
df_train.plot(kind = "line", y = ["LOG_VALOR"], ax = axes[0], title = 'Train');
df_test.plot(kind = "line", y = ["LOG_VALOR"], ax = axes[1], title = 'Test');
plt.show()

# %%
model_log = smf.ols('LOG_VALOR ~ DATAINDEX ', data = df_train).fit()

# %%
df_train["LOG_TREND"] = model_log.predict(df_train[["DATAINDEX"]])
df_test["LOG_TREND"] = model_log.predict(df_test[["DATAINDEX"]])

# %%
df_train['BACK_LOG_TREND'] = np.exp(df_train['LOG_TREND'])
df_test['BACK_LOG_TREND'] = np.exp(df_test['LOG_TREND'])

# %%
fig, axes = plt.subplots(1, 2,figsize = (10, 5))
df_train.plot(kind = "line", y = ["VALOR", "BACK_LOG_TREND"], ax = axes[0], title = 'Train');
df_test.plot(kind = "line", y = ["VALOR", "BACK_LOG_TREND"], ax = axes[1], title = 'Test');
plt.show()

# %%
model_RMSE = RMSE(df_test.BACK_LOG_TREND, df_test.VALOR)

# %%
df_Results.loc[2, "Model"] = "BACK_LOG_TREND"
df_Results.loc[2, "RMSE"] = model_RMSE
df_Results.head()
# Out:
#             Model        RMSE
# 0     LinearTrend  521.986297
# 1  QUADRATIC_TEND  503.214446
# 2  BACK_LOG_TREND  495.838421

# %% [markdown]
# # 4 - Single Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
#model_exp_smoothing_03 = SimpleExpSmoothing(df_train.VALOR).fit(smoothing_level = 0.3, optimized = False)
model_exp_smoothing_03 = SimpleExpSmoothing(df_train.VALOR).fit(smoothing_level = 0.3, optimized = False)
model_exp_smoothing_05 = SimpleExpSmoothing(df_train.VALOR).fit(smoothing_level = 0.5, optimized = False)
model_exp_smoothing_08 = SimpleExpSmoothing(df_train.VALOR).fit(smoothing_level = 0.8, optimized = False)

# %%
df_train.plot(kind = "line", y = "VALOR", color = 'yellow')
#model_exp_smoothing_03.fittedvalues.plot(label = "alpha=0.3", color = 'b');
model_exp_smoothing_03.fittedvalues.plot(label = "alpha=0.3", color = 'b');
model_exp_smoothing_05.fittedvalues.plot(label = "alpha=0.5", color = 'r');
model_exp_smoothing_08.fittedvalues.plot(label = "alpha=0.8", color = 'g');
plt.legend();

# %%
df_test["Simple_Smoothing_03"] = model_exp_smoothing_03.forecast(len(df_test))
df_test["Simple_Smoothing_05"] = model_exp_smoothing_05.forecast(len(df_test))
df_test["Simple_Smoothing_08"] = model_exp_smoothing_08.forecast(len(df_test))

# %%
model_RMSE_3 = RMSE(df_test["Simple_Smoothing_03"], df_test.VALOR)
model_RMSE_5 = RMSE(df_test["Simple_Smoothing_05"], df_test.VALOR)
model_RMSE_8 = RMSE(df_test["Simple_Smoothing_08"], df_test.VALOR)

# %%
# Calculamos o RMSE e armazenamos os resultados
df_Results.loc[3, "Model"] = "SIMPLE SMOOTHINF a=0.3"; df_Results.loc[3, "RMSE"] = model_RMSE_3
df_Results.loc[4, "Model"] = "SIMPLE SMOOTHINF a=0.5"; df_Results.loc[4, "RMSE"] = model_RMSE_5
df_Results.loc[5, "Model"] = "SIMPLE SMOOTHINF a=0.8"; df_Results.loc[5, "RMSE"] = model_RMSE_8
df_Results
# Out:
#                     Model        RMSE
# 0             LinearTrend  521.986297
# 1          QUADRATIC_TEND  503.214446
# 2          BACK_LOG_TREND  495.838421
# 3  SIMPLE SMOOTHINF a=0.3  461.098195
# 4  SIMPLE SMOOTHINF a=0.5  490.598872
# 5  SIMPLE SMOOTHINF a=0.8  571.833845

# %%
# Holt Winter Multiplicativo com Drift
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
model = ExponentialSmoothing(df_train.VALOR,
                             trend = "add",
                             seasonal = "add",
                             seasonal_periods = 30).fit()

# %%
predictions = model.forecast(12)

# %%
df_train['VALOR'].plot(legend = True, label = 'Train', figsize = (10,6))
predictions.plot (legend = True, label = 'Test')
# Out:
# <AxesSubplot:xlabel='DATA'>

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(df_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [261], in <cell line: 1>()
# ----> 1 np.sqrt(mean_squared_error(df_test,predictions))
#
# File ~\anaconda3\envs\Alex\lib\site-packages\sklearn\metrics\_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\envs\Alex\lib\site-packages\sklearn\metrics\_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     108     y_pred = y_pred.reshape((-1, 1))
#     110 if y_true.shape[1] != y_pred.shape[1]:
# --> 111     raise ValueError(
#     112         "y_true and y_pred have different number of output ({0}!={1})".format(
#     113             y_true.shape[1], y_pred.shape[1]
#     114         )
#     115     )
#     117 n_outputs = y_true.shape[1]
#     118 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (2!=1)

# %%
df_test.drop('DATAINDEX', axis=1)
# Out:
#                   VALOR
# DATA
# 2021-01-01  3352.800428
# 2021-02-01  3695.979374
# 2021-03-01  4501.917836
# 2021-04-01  4408.051057
# 2021-05-01  3630.518542
# 2021-06-01  4799.527276
# 2021-07-01  4026.993576
# 2021-08-01  3839.623568
# 2021-09-01  3931.137219
# 2021-10-01  3710.122383
# 2021-11-01  3296.592830
# 2021-12-01  3427.125288

# %%
predictions
# Out:
# 2021-01-01    4139.883936
# 2021-02-01    4316.844285
# 2021-03-01    4279.654698
# 2021-04-01    4128.835560
# 2021-05-01    4330.696839
# 2021-06-01    4492.980226
# 2021-07-01    4284.937429
# 2021-08-01    4313.747199
# 2021-09-01    4437.321747
# 2021-10-01    4451.998671
# 2021-11-01    4593.709086
# 2021-12-01    4520.819748
# Freq: MS, dtype: float64
